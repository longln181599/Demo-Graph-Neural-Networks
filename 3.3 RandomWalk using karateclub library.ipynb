# %%
" Workshop on deepWalk Algorithm using Karate Club "
import networkx as nx
G = nx.karate_club_graph()      # load the Zachary's karate club graph
print("Number of nodes (club-members)", len(G.nodes))
nx.draw_networkx(G)
# Out:
# Number of nodes (club-members) 34

# %%
" plot the graph with labels "
labels = []
for i in G.nodes:
    club_names = G.nodes[i]["club"]
    labels.append(1 if club_names == "Officer" else 0)  # Clubs: "Officer" or "Mr.Hi"

layout_pos = nx.spring_layout(G)
nx.draw_networkx(G,pos = layout_pos, node_color= labels, cmap="coolwarm")

# %%
" Perform node embedding using DeepWalk "
from karateclub import DeepWalk

DeepWalk_model = DeepWalk(walk_number=10, walk_length=80, dimensions=124)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\longln3\OneDrive - TAP DOAN VINGROUP\Desktop\Demo-Graph-Neural-Networks\3.3 RandomWalk using karateclub library.ipynb Cell 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/longln3/OneDrive%20-%20TAP%20DOAN%20VINGROUP/Desktop/Demo-Graph-Neural-Networks/3.3%20RandomWalk%20using%20karateclub%20library.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> " Perform node embedding using DeepWalk "
# ----> <a href='vscode-notebook-cell:/c%3A/Users/longln3/OneDrive%20-%20TAP%20DOAN%20VINGROUP/Desktop/Demo-Graph-Neural-Networks/3.3%20RandomWalk%20using%20karateclub%20library.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> from karateclub import DeepWalk
#       <a href='vscode-notebook-cell:/c%3A/Users/longln3/OneDrive%20-%20TAP%20DOAN%20VINGROUP/Desktop/Demo-Graph-Neural-Networks/3.3%20RandomWalk%20using%20karateclub%20library.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> DeepWalk_model = DeepWalk(walk_number=10, walk_length=80, dimensions=124)
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\karateclub\__init__.py:1, in <module>
# ----> 1 from karateclub.community_detection import *
#       2 from karateclub.node_embedding import *
#       3 from karateclub.graph_embedding import *
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\karateclub\community_detection\__init__.py:1, in <module>
# ----> 1 from .overlapping import *
#       2 from .non_overlapping import *
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\karateclub\community_detection\overlapping\__init__.py:1, in <module>
# ----> 1 from .danmf import DANMF
#       2 from .mnmf import MNMF
#       3 from .ego_splitter import EgoNetSplitter
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\karateclub\community_detection\overlapping\danmf.py:4, in <module>
#       2 import networkx as nx
#       3 from typing import List, Dict
# ----> 4 from sklearn.decomposition import NMF
#       5 from karateclub.estimator import Estimator
#       8 class DANMF(Estimator):
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\sklearn\__init__.py:82, in <module>
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)
#     128     "show_versions",
#     129 ]
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\sklearn\base.py:17, in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#      20 )
#      21 from .utils.validation import check_X_y
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\sklearn\utils\__init__.py:22, in <module>
#      20 import warnings
#      21 import numpy as np
# ---> 22 from scipy.sparse import issparse
#      24 from .murmurhash import murmurhash3_32
#      25 from .class_weight import compute_class_weight, compute_sample_weight
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\scipy\__init__.py:136, in <module>
#     133 from scipy.version import version as __version__
#     135 # Allow distributors to run custom init code
# --> 136 from . import _distributor_init
#     138 from scipy._lib import _pep440
#     139 # In maintenance branch, change to np_maxversion N+3 if numpy is at N
#     140 # See setup.py for more details
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\scipy\_distributor_init.py:59, in <module>
#      57     os.chdir(libs_path)
#      58     for filename in glob.glob(os.path.join(libs_path, '*dll')):
# ---> 59         WinDLL(os.path.abspath(filename))
#      60 finally:
#      61     os.chdir(owd)
#
# File c:\Users\longln3\Anaconda3\envs\py38\lib\ctypes\__init__.py:373, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     370 self._FuncPtr = _FuncPtr
#     372 if handle is None:
# --> 373     self._handle = _dlopen(self._name, mode)
#     374 else:
#     375     self._handle = handle
#
# FileNotFoundError: Could not find module 'c:\Users\longln3\Anaconda3\envs\py38\lib\site-packages\scipy\.libs\libbanded5x.7PE4S675VJ62Q2FNVPMD7F5FIF53EQIT.gfortran-win_amd64.dll' (or one of its dependencies). Try using the full path with constructor syntax.
